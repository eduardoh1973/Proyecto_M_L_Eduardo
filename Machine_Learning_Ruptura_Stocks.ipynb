# %% [markdown]
# ![Nombre descriptivo](Ruptura_Stock.jpg)

# %% [markdown]
# PRESENTACION DEL PROYECTO DE MACHINE LEARNING

# %% [markdown]
# Para consolidar tu proyecto basándome en la estructura que definiste en tu bitácora, aquí tienes la organización técnica de las fuentes, las variables predictoras (inputs) y la variable objetivo (target).1.
#
# Fuente del DatasetOrigen: Kaggle.
# Nombre del Dataset: Inventory Demand Forecasting and Stockout Risk.
# Archivo: inventory_data.csv (a ubicar en data/raw/).
#
#  Definición de VariablesPara tu modelo de Machine Learning, estas son las variables que utilizaremos. He unificado los nombres según la traducción que estableciste en tu bitácora para asegurar la consistencia en el código.
#  Variables Predictoras (Features).Estas son las columnas que el modelo utilizará para encontrar patrones y aprender a predecir el riesgo:
#
#
#  Campo Original Campo Traducido Tipo de dato  ocurrent_stockstock_actualNuméricodaily_demanddemanda_diariaNuméricolead_time_daystiempo_reabastecimientoNuméricosupplier_reliabilityfiabilidad_proveedorNuméricopromotion_activepromocion_activaCategórico (Booleano)weather_impactimpacto_climaCategóricoVariable Objetivo (Target)Es la columna que tu modelo debe predecir. Es el resultado final que determina si el sistema debe alertar sobre una posible rotura.  Campo Original: stockout_riskCampo Traducido: riesgo_rupturaTipo: Binario (Sí/No o 1/0)3. Consideraciones para el Machine LearningPara cumplir con el objetivo del proyecto, el modelo se comportará como un clasificador binario.  ¿Por qué estas variables?: El stock_actual junto con la demanda_diaria y el tiempo_reabastecimiento permiten al algoritmo entender el "punto de pedido". La fiabilidad_proveedor y el impacto_clima actúan como variables de estrés que aumentan la probabilidad de que la rotura ocurra.  Integración: Al cargar el archivo en src/data_ingestion.py, aplicaremos el mapeo anterior para que todos tus archivos procesados en data/processed/ mantengan estos nombres en español, facilitando el mantenimiento y la lectura de los resultados.
