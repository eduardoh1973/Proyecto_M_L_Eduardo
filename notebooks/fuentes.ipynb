# %%
import pandas as pd

df = pd.read_csv('../data/raw/inventory_demand_stockout_risk.csv')
print(df.head())
# Out:
#   product_id        date store_id  current_stock  daily_demand  \
# 0      P1000  2024-01-01       S7            213           114
# 1      P1001  2024-01-02      S20            152            87
# 2      P1002  2024-01-03      S15            209            62
# 3      P1003  2024-01-04      S11            400           103
# 4      P1004  2024-01-05       S8             60           114
#
#    lead_time_days  supplier_reliability_score promotion_active weather_impact  \
# 0               5                          72               No         Medium
# 1               7                          84               No           High
# 2              10                          61               No            Low
# 3              10                          61               No            Low
# 4               9                          75               No         Medium
#
#   stockout_risk
# 0            No
# 1           Yes
# 2            No
# 3            No
# 4            No

# %%
df = pd.read_csv('../data/raw/inventory_demand_stockout_risk.csv')
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 2800 entries, 0 to 2799
# Data columns (total 10 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   product_id                  2800 non-null   str
#  1   date                        2800 non-null   str
#  2   store_id                    2800 non-null   str
#  3   current_stock               2800 non-null   int64
#  4   daily_demand                2800 non-null   int64
#  5   lead_time_days              2800 non-null   int64
#  6   supplier_reliability_score  2800 non-null   int64
#  7   promotion_active            2800 non-null   str
#  8   weather_impact              2800 non-null   str
#  9   stockout_risk               2800 non-null   str
# dtypes: int64(4), str(6)
# memory usage: 291.3 KB

# %%
# Convertimos la fecha a formato fecha real
df['date'] = pd.to_datetime(df['date'])

output_path = '../data/processed/inventory_clean.csv'
df.to_csv(output_path, index=False)

print(f"Dataset guardado con éxito en: {output_path}")
print("Tipos de datos actualizados:")
print(df.dtypes)
# Out:
# Dataset guardado con éxito en: ../data/processed/inventory_clean.csv
# Tipos de datos actualizados:
# product_id                               str
# date                          datetime64[us]
# store_id                                 str
# current_stock                          int64
# daily_demand                           int64
# lead_time_days                         int64
# supplier_reliability_score             int64
# promotion_active                         str
# weather_impact                           str
# stockout_risk                            str
# dtype: object
